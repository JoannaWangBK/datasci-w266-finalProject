# %% [markdown]
# # W266 Final Project Code
# # Amazon Product Review Aspect-Based Sentiment
# ## Jennifer Mahle and Joanna Wang (Sections 3 and 1, respectively)

# %%
import os
import pandas as pd

dataset = "Electronics_5.json"

if os.path.isfile(dataset):
    df = pd.read_json("Electronics_5.json", lines=True)
else:
    url = r"http://snap.stanford.edu/data/amazon/productGraph/categoryFiles/reviews_Electronics_5.json.gz"
    df = pd.read_json(url, compression='gzip', lines=True)

display(df.head(10))
# Out:
#          asin image  overall  \
# 0  0151004714   NaN        5
# 1  0151004714   NaN        3
# 2  0151004714   NaN        5
# 3  0151004714   NaN        5
# 4  0151004714   NaN        3
# 5  0380709473   NaN        4
# 6  0380709473   NaN        5
# 7  0380709473   NaN        5
# 8  0380709473   NaN        5
# 9  0380709473   NaN        4
#
#                                           reviewText   reviewTime  \
# 0  This is the best novel I have read in 2 or 3 y...  09 18, 1999
# 1  Pages and pages of introspection, in the style...  10 23, 2013
# 2  This is the kind of novel to read when you hav...   09 2, 2008
# 3  What gorgeous language! What an incredible wri...   09 4, 2000
# 4  I was taken in by reviews that compared this b...   02 4, 2000
# 5  I read this probably 50 years ago in my youth ...   06 5, 2013
# 6  I read every Perry mason book voraciously. Fin...  06 27, 2016
# 7  I love this series of Bertha and Lamb..  Great...  07 30, 2015
# 8                                        Great read!  02 16, 2015
# 9  Crows Can't Count, A.A. Fair\n\nMr. Harry Shar...  11 21, 2013
#
#        reviewerID      reviewerName                           style  \
# 0   AAP7PPBU72QFM      D. C. Carrad       {'Format:': ' Hardcover'}
# 1  A2E168DTVGE6SV               Evy  {'Format:': ' Kindle Edition'}
# 2  A1ER5AYS3FQ9O3             Kcorn       {'Format:': ' Paperback'}
# 3  A1T17LMQABMBN5   Caf Girl Writes       {'Format:': ' Hardcover'}
# 4  A3QHJ0FXK33OBE  W. Shane Schmidt       {'Format:': ' Hardcover'}
# 5  A3IYSOTP3HA77N          B. Marks  {'Format:': ' Kindle Edition'}
# 6  A11SXV34PZUQ5E            Tom C.  {'Format:': ' Kindle Edition'}
# 7  A2AUQM1HT2D5T8               ema  {'Format:': ' Kindle Edition'}
# 8  A3UD8JRWLX6SRX        Michael O.       {'Format:': ' Paperback'}
# 9  A3MV1KKHX51FYT    Acute Observer       {'Format:': ' Paperback'}
#
#                                              summary  unixReviewTime  \
# 0                                     A star is born       937612800
# 1                    A stream of consciousness novel      1382486400
# 2  I'm a huge fan of the author and this one did ...      1220313600
# 3          The most beautiful book I have ever read!       968025600
# 4                        A dissenting view--In part.       949622400
# 5                              Above average mystery      1370390400
# 6                                       Lam is cool!      1466985600
# 7                                         Five Stars      1438214400
# 8                                         Five Stars      1424044800
# 9                    A Fast and Far Moving Adventure      1384992000
#
#    verified vote
# 0      True   67
# 1      True    5
# 2     False    4
# 3     False   13
# 4      True    8
# 5      True  NaN
# 6      True  NaN
# 7      True  NaN
# 8      True  NaN
# 9     False  NaN

# %%
display(df.tail(10))
# Out:
#                asin image  overall  \
# 6739580  B01HJCN1EI   NaN        5
# 6739581  B01HJCN1EI   NaN        1
# 6739582  B01HJH42KU   NaN        3
# 6739583  B01HJH42KU   NaN        2
# 6739584  B01HJH40WU   NaN        3
# 6739585  B01HJH40WU   NaN        4
# 6739586  B01HJH40WU   NaN        4
# 6739587  B01HJH40WU   NaN        5
# 6739588  B01HJH40WU   NaN        5
# 6739589  B01HJF704M   NaN        5
#
#                                                 reviewText   reviewTime  \
# 6739580  These are my favorite charging cords for a few...  07 25, 2017
# 6739581  Update....after 2 months of gentle use, cable ...   04 4, 2017
# 6739582  These are okay. The connection becomes very if...   07 8, 2017
# 6739583  I liked the length and the product at first bu...  05 21, 2017
# 6739584                        not holding up over time :(  06 26, 2017
# 6739585  These seem like quality USB cables, time will ...  03 21, 2017
# 6739586  Works great, love the longer cord. As with any...   01 9, 2017
# 6739587  Ok here is an odd thing that happened to me, I...   12 1, 2016
# 6739588                                        Works well.  11 29, 2016
# 6739589  I have it plugged into a usb extension on my g...  03 31, 2017
#
#              reviewerID       reviewerName style  \
# 6739580  A1OOVLE2KZ6KGA            Puddzee   NaN
# 6739581   A77K1B31UAQ29  addictedtoreading   NaN
# 6739582  A2SVXUVUAWUDK2             Andrew   NaN
# 6739583  A12E1JGKV0ETAB         John Adams   NaN
# 6739584  A1HKXEX8BEQC2E     Dasha stephens   NaN
# 6739585  A33MAQA919J2V8          Kurt Wurm   NaN
# 6739586  A1AKHSCPD1BHM4         C.L Momof3   NaN
# 6739587  A2HUZO7MQAY5I2     michael clontz   NaN
# 6739588   AJJ7VX2L91X2W              Faith   NaN
# 6739589  A1FGCIRPRNZWD5             Brando   NaN
#
#                                                    summary  unixReviewTime  \
# 6739580                                   Worth the price.      1500940800
# 6739581                  UPDATE...BREAKS AND SLOW CHARGING      1491264000
# 6739582  Hope this makes sense. You'd understand if you...      1499472000
# 6739583                           Lost ability to connect.      1495324800
# 6739584                        not holding up over time :(      1498435200
# 6739585                                         Four Stars      1490054400
# 6739586                                     Nice long cord      1483920000
# 6739587     Not the correct product as linked in the sale.      1480550400
# 6739588                                         Five Stars      1480377600
# 6739589                                Works well enough..      1490918400
#
#          verified vote
# 6739580      True  NaN
# 6739581      True  NaN
# 6739582      True  NaN
# 6739583      True  NaN
# 6739584      True  NaN
# 6739585      True  NaN
# 6739586      True  NaN
# 6739587      True    2
# 6739588      True    2
# 6739589      True  NaN

# %%
df.shape
# Out:
# (6739590, 12)

# %%
no_NA_reviews = df.dropna(subset=['reviewText'])
no_NA_reviews.shape
# Out:
# (6738237, 12)

# %%
# Remove ## from lines starting with ! and run them the first time to install necessary packages 

##%%capture
# Install the latest Tensorflow version.
##!pip3 install --upgrade tensorflow-gpu
# Install TF-Hub.
##!pip3 install tensorflow-hub
##!pip3 install seaborn

# %%
#@title Load the Universal Sentence Encoder's TF Hub module
from absl import logging

import tensorflow as tf
import tensorflow_hub as hub
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import re
import seaborn as sns

module_url = "https://tfhub.dev/google/universal-sentence-encoder/4" #@param ["https://tfhub.dev/google/universal-sentence-encoder/4", "https://tfhub.dev/google/universal-sentence-encoder-large/5"]
model = hub.load(module_url)
print ("module %s loaded" % module_url)
def embed(input):
  return model(input)
# Out:
# module https://tfhub.dev/google/universal-sentence-encoder/4 loaded

# %%
#split the data into training and testing data, using "overall" as the target variable
y=no_NA_reviews.overall
x=no_NA_reviews.drop('overall',axis=1)

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

logging.set_verbosity(logging.ERROR)

#create embeddings on the training data 
message_embeddings = embed(x_train.reviewText)

# %%
print("Training X Shape", x_train.shape)
print("Testing X Shape", x_test.shape)
# Out:
# Training X Shape (5390589, 11)
# Testing X Shape (1347648, 11)
