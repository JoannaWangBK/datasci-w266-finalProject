# %%
# Installing package
# !pip install gensim

# Importing libraries
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import nltk
import string
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from sklearn.feature_extraction.text import CountVectorizer
from nltk.stem.porter import PorterStemmer
import re
import string
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer

from gensim.models import Word2Vec
from gensim.models import KeyedVectors
import pickle
# Out:
# Requirement already satisfied: gensim in /home/wangjia/anaconda3/lib/python3.7/site-packages (3.8.1)
# Requirement already satisfied: six>=1.5.0 in /home/wangjia/anaconda3/lib/python3.7/site-packages (from gensim) (1.12.0)
# Requirement already satisfied: numpy>=1.11.3 in /home/wangjia/anaconda3/lib/python3.7/site-packages (from gensim) (1.17.2)
# Requirement already satisfied: smart-open>=1.8.1 in /home/wangjia/anaconda3/lib/python3.7/site-packages (from gensim) (1.9.0)
# Requirement already satisfied: scipy>=0.18.1 in /home/wangjia/anaconda3/lib/python3.7/site-packages (from gensim) (1.4.1)
# Requirement already satisfied: requests in /home/wangjia/anaconda3/lib/python3.7/site-packages (from smart-open>=1.8.1->gensim) (2.22.0)
# Requirement already satisfied: boto3 in /home/wangjia/anaconda3/lib/python3.7/site-packages (from smart-open>=1.8.1->gensim) (1.12.16)
# Requirement already satisfied: boto>=2.32 in /home/wangjia/anaconda3/lib/python3.7/site-packages (from smart-open>=1.8.1->gensim) (2.49.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/wangjia/anaconda3/lib/python3.7/site-packages (from requests->smart-open>=1.8.1->gensim) (1.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/wangjia/anaconda3/lib/python3.7/site-packages (from requests->smart-open>=1.8.1->gensim) (2019.9.11)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/wangjia/anaconda3/lib/python3.7/site-packages (from requests->smart-open>=1.8.1->gensim) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/wangjia/anaconda3/lib/python3.7/site-packages (from requests->smart-open>=1.8.1->gensim) (2.8)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/wangjia/anaconda3/lib/python3.7/site-packages (from boto3->smart-open>=1.8.1->gensim) (0.9.5)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /home/wangjia/anaconda3/lib/python3.7/site-packages (from boto3->smart-open>=1.8.1->gensim) (0.3.3)
# Requirement already satisfied: botocore<1.16.0,>=1.15.16 in /home/wangjia/anaconda3/lib/python3.7/site-packages (from boto3->smart-open>=1.8.1->gensim) (1.15.16)
# Requirement already satisfied: docutils<0.16,>=0.10 in /home/wangjia/anaconda3/lib/python3.7/site-packages (from botocore<1.16.0,>=1.15.16->boto3->smart-open>=1.8.1->gensim) (0.15.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/wangjia/anaconda3/lib/python3.7/site-packages (from botocore<1.16.0,>=1.15.16->boto3->smart-open>=1.8.1->gensim) (2.8.0)

# %%
import os
import pandas as pd

dataset = "Electronics_5.json"

if os.path.isfile(dataset):
    df = pd.read_json("Electronics_5.json", lines=True)
else:
    url = r"http://deepyeti.ucsd.edu/jianmo/amazon/categoryFilesSmall/Electronics_5.json.gz"
    df = pd.read_json(url, compression='gzip', lines=True)

display(df.tail(10))
df.shape
print(df.info())
# Out:
#          overall vote  verified   reviewTime      reviewerID        asin  \
# 6739580        5  NaN      True  07 25, 2017  A1OOVLE2KZ6KGA  B01HJCN1EI
# 6739581        1  NaN      True   04 4, 2017   A77K1B31UAQ29  B01HJCN1EI
# 6739582        3  NaN      True   07 8, 2017  A2SVXUVUAWUDK2  B01HJH42KU
# 6739583        2  NaN      True  05 21, 2017  A12E1JGKV0ETAB  B01HJH42KU
# 6739584        3  NaN      True  06 26, 2017  A1HKXEX8BEQC2E  B01HJH40WU
# 6739585        4  NaN      True  03 21, 2017  A33MAQA919J2V8  B01HJH40WU
# 6739586        4  NaN      True   01 9, 2017  A1AKHSCPD1BHM4  B01HJH40WU
# 6739587        5    2      True   12 1, 2016  A2HUZO7MQAY5I2  B01HJH40WU
# 6739588        5    2      True  11 29, 2016   AJJ7VX2L91X2W  B01HJH40WU
# 6739589        5  NaN      True  03 31, 2017  A1FGCIRPRNZWD5  B01HJF704M
#
#         style       reviewerName  \
# 6739580   NaN            Puddzee
# 6739581   NaN  addictedtoreading
# 6739582   NaN             Andrew
# 6739583   NaN         John Adams
# 6739584   NaN     Dasha stephens
# 6739585   NaN          Kurt Wurm
# 6739586   NaN         C.L Momof3
# 6739587   NaN     michael clontz
# 6739588   NaN              Faith
# 6739589   NaN             Brando
#
#                                                 reviewText  \
# 6739580  These are my favorite charging cords for a few...
# 6739581  Update....after 2 months of gentle use, cable ...
# 6739582  These are okay. The connection becomes very if...
# 6739583  I liked the length and the product at first bu...
# 6739584                        not holding up over time :(
# 6739585  These seem like quality USB cables, time will ...
# 6739586  Works great, love the longer cord. As with any...
# 6739587  Ok here is an odd thing that happened to me, I...
# 6739588                                        Works well.
# 6739589  I have it plugged into a usb extension on my g...
#
#                                                    summary  unixReviewTime  \
# 6739580                                   Worth the price.      1500940800
# 6739581                  UPDATE...BREAKS AND SLOW CHARGING      1491264000
# 6739582  Hope this makes sense. You'd understand if you...      1499472000
# 6739583                           Lost ability to connect.      1495324800
# 6739584                        not holding up over time :(      1498435200
# 6739585                                         Four Stars      1490054400
# 6739586                                     Nice long cord      1483920000
# 6739587     Not the correct product as linked in the sale.      1480550400
# 6739588                                         Five Stars      1480377600
# 6739589                                Works well enough..      1490918400
#
#         image
# 6739580   NaN
# 6739581   NaN
# 6739582   NaN
# 6739583   NaN
# 6739584   NaN
# 6739585   NaN
# 6739586   NaN
# 6739587   NaN
# 6739588   NaN
# 6739589   NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6739590 entries, 0 to 6739589
# Data columns (total 12 columns):
# overall           int64
# vote              object
# verified          bool
# reviewTime        object
# reviewerID        object
# asin              object
# style             object
# reviewerName      object
# reviewText        object
# summary           object
# unixReviewTime    int64
# image             object
# dtypes: bool(1), int64(2), object(9)
# memory usage: 572.0+ MB
# None

# %%
filtered_data = df[df['overall'] != 3]
def polarity(x):
    if x < 3:
        return 0
    return 1

# Applying polarity function on Score column of filtered_data
filtered_data['overall'] = filtered_data['overall'].map(polarity)

print(filtered_data.shape)
filtered_data.tail(10)
# Out:
# (6234809, 12)
#          overall vote  verified   reviewTime      reviewerID        asin  \
# 6739577        1  NaN      True   03 9, 2018  A1KB3JXELNI0A8  B01HJFFHTC
# 6739579        1  NaN      True  12 14, 2017  A2HE7TX3FE1RLE  B01HJFFHTC
# 6739580        1  NaN      True  07 25, 2017  A1OOVLE2KZ6KGA  B01HJCN1EI
# 6739581        0  NaN      True   04 4, 2017   A77K1B31UAQ29  B01HJCN1EI
# 6739583        0  NaN      True  05 21, 2017  A12E1JGKV0ETAB  B01HJH42KU
# 6739585        1  NaN      True  03 21, 2017  A33MAQA919J2V8  B01HJH40WU
# 6739586        1  NaN      True   01 9, 2017  A1AKHSCPD1BHM4  B01HJH40WU
# 6739587        1    2      True   12 1, 2016  A2HUZO7MQAY5I2  B01HJH40WU
# 6739588        1    2      True  11 29, 2016   AJJ7VX2L91X2W  B01HJH40WU
# 6739589        1  NaN      True  03 31, 2017  A1FGCIRPRNZWD5  B01HJF704M
#
#         style       reviewerName  \
# 6739577   NaN       Miguel Roman
# 6739579   NaN       Electroronto
# 6739580   NaN            Puddzee
# 6739581   NaN  addictedtoreading
# 6739583   NaN         John Adams
# 6739585   NaN          Kurt Wurm
# 6739586   NaN         C.L Momof3
# 6739587   NaN     michael clontz
# 6739588   NaN              Faith
# 6739589   NaN             Brando
#
#                                                 reviewText  \
# 6739577                                         Works well
# 6739579  Worked very well for my car that didn't have a...
# 6739580  These are my favorite charging cords for a few...
# 6739581  Update....after 2 months of gentle use, cable ...
# 6739583  I liked the length and the product at first bu...
# 6739585  These seem like quality USB cables, time will ...
# 6739586  Works great, love the longer cord. As with any...
# 6739587  Ok here is an odd thing that happened to me, I...
# 6739588                                        Works well.
# 6739589  I have it plugged into a usb extension on my g...
#
#                                                 summary  unixReviewTime image
# 6739577                                      Five Stars      1520553600   NaN
# 6739579                                    great format      1513209600   NaN
# 6739580                                Worth the price.      1500940800   NaN
# 6739581               UPDATE...BREAKS AND SLOW CHARGING      1491264000   NaN
# 6739583                        Lost ability to connect.      1495324800   NaN
# 6739585                                      Four Stars      1490054400   NaN
# 6739586                                  Nice long cord      1483920000   NaN
# 6739587  Not the correct product as linked in the sale.      1480550400   NaN
# 6739588                                      Five Stars      1480377600   NaN
# 6739589                             Works well enough..      1490918400   NaN

# %%
#Sorting data according to asin in ascending order
sorted_data=filtered_data.sort_values('asin', axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last')

#Deduplication of entries
final=sorted_data.drop_duplicates(subset={"reviewerID","reviewerName","reviewText","summary"}, keep='first', inplace=False)

#Removed not verified rows
final = final[final.verified != False]

final = final.dropna(subset=['reviewText'])
print(final.shape)
final[30:50]
# Out:
# (5014145, 12)
#          overall vote  verified   reviewTime      reviewerID        asin  \
# 6099812        0  NaN      True  01 17, 2012  A1WQX8VFYHPO4P  0446697192
# 29             0  NaN      True  12 11, 2015  A2R9IT1MU2LOJW  0511189877
# 28             1  NaN      True  01 14, 2016  A1KV65E2TMMG6F  0511189877
# 27             1  NaN      True  02 29, 2016   A8COCL8EE1CQH  0511189877
# 26             1  NaN      True  03 10, 2016  A12JHGROAX49G7  0511189877
# 24             1  NaN      True   06 6, 2016  A2NETQRG6JHIG7  0511189877
# 23             1  NaN      True  07 26, 2016  A24VW8XTD8LSXE  0511189877
# 22             1  NaN      True  08 14, 2016  A17BMVVA8MND5C  0511189877
# 21             1  NaN      True  08 25, 2016  A2I2KPNJDQ9SL0  0511189877
# 30             1  NaN      True   11 6, 2015  A2Z1YRCYRMEVGS  0511189877
# 17             1  NaN      True  05 31, 2017   A7362LXMQEM6W  0511189877
# 6099816        1  NaN      True  03 12, 2018  A2FRC7HJRIZ05T  0511189877
# 35             1  NaN      True   08 5, 2015  A3J6X6RXNRHM8V  0511189877
# 33             1  NaN      True  09 28, 2015  A18QXOKJ91HUV0  0511189877
# 36             1  NaN      True  07 22, 2015  A1D4UFZ9X6U5UW  0511189877
# 37             1  NaN      True  06 30, 2015  A2R8N42G5EDN91  0511189877
# 38             1  NaN      True  06 10, 2015  A1VJ8WQJ5X5F5M  0511189877
# 39             1  NaN      True  05 30, 2015  A3MWIVHMDTODH1  0511189877
# 40             1  NaN      True   05 9, 2015  A3HZFOY6YU5BKD  0511189877
# 41             1  NaN      True  04 13, 2015  A1A5GOE5E7BL9S  0511189877
#
#                                   style       reviewerName  \
# 6099812  {'Format:': ' Kindle Edition'}         Cherriej63
# 29                                  NaN              Arwen
# 28                                  NaN      Dane Williams
# 27                                  NaN            anthony
# 26                                  NaN            Linwood
# 24                                  NaN       Qrysta White
# 23                                  NaN    Amazon Customer
# 22                                  NaN        Logopolitan
# 21                                  NaN              aJayM
# 30                                  NaN             obidon
# 17                                  NaN     Online shopper
# 6099816                             NaN      Carl Matthews
# 35                                  NaN       Aaron Weaver
# 33                                  NaN                 GE
# 36                                  NaN         Lithia Leo
# 37                                  NaN                PJP
# 38                                  NaN        Chocol8drop
# 39                                  NaN          Rhonda G.
# 40                                  NaN  Charles R. Miller
# 41                                  NaN   Gerald D. Schrag
#
#                                                 reviewText  \
# 6099812  I should have read the description of the book...
# 29       Volume buttons were dead on arrival. be aware ...
# 28       I got tired of the remote being on the wrong s...
# 27                                    Works like it should
# 26       Got them and only 2 of them worked. company ca...
# 24       First time I've EVER had a remote that needed ...
# 23                                             Works great
# 22                                           very nice....
# 21       Came with a "bright house networks" logo, but ...
# 30                              Works fine easy to program
# 17       Worked out of the box with my cable box in nor...
# 6099816             Functions just a good as the original.
# 35                                          worked. cheap.
# 33                     excellent!  delivery was immediate.
# 36       Works just like the rental unit supplied by th...
# 37                                                   great
# 38                                         awesome product
# 39       I love the remote, my old remote was going bad...
# 40                             GREAT PRICE... GREAT REMOTE
# 41       An excellent product/price, and super-fast shi...
#
#                                                    summary  unixReviewTime  \
# 6099812                                 Incredibly cliche.      1326758400
# 29                                                One Star      1449792000
# 28                                      Same as TWC remote      1452729600
# 27                                   Exactly what you need      1456704000
# 26                           Works Good and programs easy.      1457568000
# 24                     zero programming needed!  Miracle!?      1465171200
# 23                                              Five Stars      1469491200
# 22                                              Five Stars      1471132800
# 21                                                   Works      1472083200
# 30                                              Five Stars      1446768000
# 17                                         Paid full price      1496188800
# 6099816              Good replacement remote for original.      1520812800
# 35       if the cable company is a dick. just buy one f...      1438732800
# 33                       excellent! delivery was immediate      1443398400
# 36       Works just like the rental unit supplied by th...      1437523200
# 37                                              Five Stars      1435622400
# 38                                              Five Stars      1433894400
# 39                                            works great!      1432944000
# 40                                              Four Stars      1431129600
# 41                                    A direct replacement      1428883200
#
#                                                      image
# 6099812                                                NaN
# 29                                                     NaN
# 28                                                     NaN
# 27                                                     NaN
# 26                                                     NaN
# 24                                                     NaN
# 23                                                     NaN
# 22                                                     NaN
# 21                                                     NaN
# 30                                                     NaN
# 17       [https://images-na.ssl-images-amazon.com/image...
# 6099816                                                NaN
# 35                                                     NaN
# 33                                                     NaN
# 36                                                     NaN
# 37                                                     NaN
# 38                                                     NaN
# 39                                                     NaN
# 40                                                     NaN
# 41                                                     NaN

# %%
# Downloading stopwords
nltk.download('stopwords')

#set of stopwords in English
from nltk.corpus import stopwords
stop = set(stopwords.words('english'))
words_to_keep = set(('not'))
stop -= words_to_keep
#initialising the snowball stemmer
sno = nltk.stem.SnowballStemmer('english')

 #function to clean the word of any html-tags
def cleanhtml(sentence):
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, ' ', sentence)
    return cleantext

#function to clean the word of any punctuation or special characters
def cleanpunc(sentence): 
    cleaned = re.sub(r'[?|!|\'|"|#]',r'',sentence)
    cleaned = re.sub(r'[.|,|)|(|\|/]',r' ',cleaned)
    return  cleaned
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/wangjia/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#Create a mini set by selecting 1000 rows randomly 
final_mini= final.sample(n=1000)
final_mini.reviewText.iloc[500]
# Out:
# "It's 1080p, it's cheap. Looks fine, but there are higher quality monitors out there."

# %%
#Code for removing HTML tags , punctuations . Code for removing stopwords . Code for checking if word is not alphanumeric and
# also greater than 2 . Code for stemmimg and also to convert them to lowercase letters 

i=0
str1=' '
final_string=[]
all_positive_words=[] # store words from +ve reviews here
all_negative_words=[] # store words from -ve reviews here.
s=''
for sent in final_mini.reviewText:
    filtered_sentence=[]
    #print(sent);
    sent=cleanhtml(sent) # remove HTMl tags
    for w in sent.split():
        for cleaned_words in cleanpunc(w).split():
            if((cleaned_words.isalpha()) & (len(cleaned_words)>2)):    
                if(cleaned_words.lower() not in stop):
                    s=(sno.stem(cleaned_words.lower())).encode('utf8')
                    filtered_sentence.append(s)
                    if (final_mini['reviewText'].values)[i] == 1: 
                        all_positive_words.append(s) #list of all words used to describe positive reviews
                    if(final_mini['reviewText'].values)[i] == 0:
                        all_negative_words.append(s) #list of all words used to describe negative reviews reviews
                else:
                    continue
            else:
                continue 
    
    str1 = b" ".join(filtered_sentence) #final string of cleaned words
    
    
    final_string.append(str1)
    i+=1

# %%
len(final_string)
# Out:
# 1000

# %%
#adding a column of CleanedText which displays the data after pre-processing of the review
final_mini['CleanedText']=final_string  
final_mini['CleanedText']=final_mini['CleanedText'].str.decode("utf-8")
#below the processed review can be seen in the CleanedText Column 
print('Shape of final',final_mini.shape)
final_mini.head()
# Out:
# Shape of final (1000, 13)
#          overall vote  verified   reviewTime      reviewerID        asin  \
# 6039027        0   14      True  12 13, 2016  A210XA1V8GUHXL  B01FWI7J7G
# 2235334        1  NaN      True  05 18, 2014  A2L8NERGVGD7NV  B005HPYGTO
# 6640126        1  NaN      True   05 7, 2016  A2BCGKWKA8M317  B00YXYZPD6
# 5386752        1  NaN      True   03 9, 2017   AB7B06HYQBCNM  B0117RFPCC
# 2503725        1  NaN      True  03 11, 2014  A10CTV78GVGWN0  B006YNTJ6I
#
#                                                      style   reviewerName  \
# 6039027  {'Size:': ' Base Clock 1607 MHz', 'Style:': ' ...       xStealth
# 2235334                                 {'Color:': ' Red'}         ohemaa
# 6640126                                                NaN             KC
# 5386752                                                NaN           Nate
# 2503725           {'Package Type:': ' Standard Packaging'}  Jasmine Staup
#
#                                                 reviewText  \
# 6039027  Received card, uninstalled my NVIDIA drivers t...
# 2235334  Great quality. Side pocket is not big enough t...
# 6640126                                      As advertised
# 5386752  Amazing ear buds.  Fit great, and they come wi...
# 2503725  I ordered two by accident and I actually could...
#
#                         summary  unixReviewTime image  \
# 6039027  Might have been a dud?      1481587200   NaN
# 2235334           Great Case!!!      1400371200   NaN
# 6640126              Five Stars      1462579200   NaN
# 5386752        Amazing ear buds      1489017600   NaN
# 2503725  What I was looking for      1394496000   NaN
#
#                                                CleanedText
# 6039027  receiv card uninstal nvidia driver power syste...
# 2235334  great qualiti side pocket big enough hold anyt...
# 6640126                                           advertis
# 5386752  amaz ear bud fit great come option insert diff...
# 2503725  order two accid actual couldnt get fit ipod cl...

# %%
x = final_mini['CleanedText'].values
y = final_mini['overall']

# Finding all words in the vocabulary
count_vect = CountVectorizer() 
count_vect.fit(x)

vocabulary = count_vect.get_feature_names()
print('No. of words in the Vocabulary : ',len(vocabulary))
# Out:
# No. of words in the Vocabulary :  3560

# %%
# Storing all words in the dictionary (words as keys and index as values)
corpus = dict()
ind = 0
for sent in x:
  for word in sent.split():
    corpus.setdefault(word,[])
    corpus[word].append(ind)
    ind += 1

# Getting frequency for each word of vocabulary and storing it in a list
freq = []
for w in vocabulary:
  freq.append(len(corpus[w]))

# %%
# Getting Index for each word in the vocabulary
# Sorting frequencies in decreasing order
inc_index =np.argsort(np.array(freq))[::-1]

# Allocating ranks to words of vocabulary in decreasing order of frequency and storing words in a dictionary
word_rank = dict()
rank = 1
for i in inc_index:
  word_rank[vocabulary[i]] = rank
  rank +=1

# %%
# Converting full data into imdb format
data = []
for sent in x:
  row = []
  for word in sent.split():
    if(len(word)>1):
      row.append(word_rank[word])
  data.append(row)

# %%
from sklearn.model_selection import train_test_split
#split the data into training and testing data, using "overall" as the target variable
y=final_mini.overall
#x=final_mini.drop('overall',axis=1)
x_train,x_test,y_train,y_test=train_test_split(data,y,test_size=0.2)
print("No. of datapoints in x_train :",len(x_train))
print("No. of datapoints in x_test :",len(x_test))
print("Shape of y_train :",y_train.shape)
print("Shape of y_test :",y_test.shape)
# Out:
# No. of datapoints in x_train : 800
# No. of datapoints in x_test : 200
# Shape of y_train : (800,)
# Shape of y_test : (200,)

# %%
# !pip3 install keras
# Out:
# Requirement already satisfied: keras in /home/wangjia/anaconda3/lib/python3.7/site-packages (2.3.1)
# Requirement already satisfied: six>=1.9.0 in /home/wangjia/anaconda3/lib/python3.7/site-packages (from keras) (1.12.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /home/wangjia/anaconda3/lib/python3.7/site-packages (from keras) (1.0.8)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /home/wangjia/anaconda3/lib/python3.7/site-packages (from keras) (1.1.0)
# Requirement already satisfied: numpy>=1.9.1 in /home/wangjia/anaconda3/lib/python3.7/site-packages (from keras) (1.17.2)
# Requirement already satisfied: scipy>=0.14 in /home/wangjia/anaconda3/lib/python3.7/site-packages (from keras) (1.4.1)
# Requirement already satisfied: pyyaml in /home/wangjia/anaconda3/lib/python3.7/site-packages (from keras) (5.1.2)
# Requirement already satisfied: h5py in /home/wangjia/anaconda3/lib/python3.7/site-packages (from keras) (2.9.0)

# %%
# Importing libraries
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence
from keras.layers import Dropout
# fix random seed for reproducibility
np.random.seed(7)
# Out:
# Using TensorFlow backend.

# %%
# truncate and/or pad input sequences
max_review_length = 100
x_train = sequence.pad_sequences(x_train, maxlen=max_review_length)
x_test = sequence.pad_sequences(x_test, maxlen=max_review_length)

print(x_train.shape)
print(x_train[1])
# Out:
# (800, 100)
# [   0    0    0    0    0    0   19   78 1481  514 2077  940   52   42
#   613   64 3358  120   13 2166   81   44  455 1095   36 2260  595  309
#   940   81  147 1537   14   18  655 1939 3343 1539 1006  994  402 1481
#    79  295 2191  323  174  478   46   55 1347  195  478  185  195  313
#   238  174 1431   14   17   26   46  335  882 1192    4  101  595  205
#     6  185  136  524 1734 2185  502   21 3386   26   14  720  301  386
#    21  974 2301   87  137  315 2038   38    3  929  294  614   41 1175
#   254   64]

# %%
# this function is used draw Binary Crossentropy Loss VS No. of epochs plot
def plt_dynamic(x, vy, ty):
  plt.figure(figsize=(10,5))
  plt.plot(x, vy, 'b', label="Validation Loss")
  plt.plot(x, ty, 'r', label="Train Loss")
  plt.xlabel('Epochs') 
  plt.ylabel('Binary Crossentropy Loss')
  plt.title('\nBinary Crossentropy Loss VS Epochs')
  plt.legend()
  plt.grid()
  plt.show()

# %%
# create the model
embedding_vecor_length = 32

# Initialising the model
model_1 = Sequential()

# Adding embedding
model_1.add(Embedding(len(vocabulary), embedding_vecor_length, input_length=max_review_length))

# Adding Dropout
model_1.add(Dropout(0.2))

# Adding first LSTM layer
model_1.add(LSTM(100))

# Adding Dropout
model_1.add(Dropout(0.2))

# Adding output layer
model_1.add(Dense(1, activation='sigmoid'))

# Printing the model summary
print(model_1.summary())

# Compiling the model
model_1.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Fitting the data to the model
history_1 = model_1.fit(x_train, y_train, nb_epoch=10, batch_size=512 ,verbose=1,validation_data=(x_test, y_test))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 100, 32)           113920
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100, 32)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100)               53200
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 167,221
# Trainable params: 167,221
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 800 samples, validate on 200 samples
# Epoch 1/10
# 800/800 [==============================] - 4s 5ms/step - loss: 0.6911 - accuracy: 0.5788 - val_loss: 0.6768 - val_accuracy: 0.8750
# Epoch 2/10
# 800/800 [==============================] - 1s 966us/step - loss: 0.6742 - accuracy: 0.8712 - val_loss: 0.6553 - val_accuracy: 0.8750
# Epoch 3/10
# 800/800 [==============================] - 1s 893us/step - loss: 0.6523 - accuracy: 0.8712 - val_loss: 0.6213 - val_accuracy: 0.8750
# Epoch 4/10
# 800/800 [==============================] - 1s 901us/step - loss: 0.6146 - accuracy: 0.8712 - val_loss: 0.5559 - val_accuracy: 0.8750
# Epoch 5/10
# 800/800 [==============================] - 1s 898us/step - loss: 0.5415 - accuracy: 0.8712 - val_loss: 0.3993 - val_accuracy: 0.8750
# Epoch 6/10
# 800/800 [==============================] - 1s 870us/step - loss: 0.4055 - accuracy: 0.8712 - val_loss: 0.3966 - val_accuracy: 0.8750
# Epoch 7/10
# 800/800 [==============================] - 1s 892us/step - loss: 0.4112 - accuracy: 0.8712 - val_loss: 0.3622 - val_accuracy: 0.8750
# Epoch 8/10
# 800/800 [==============================] - 1s 898us/step - loss: 0.3763 - accuracy: 0.8712 - val_loss: 0.3635 - val_accuracy: 0.8750
# Epoch 9/10
# 800/800 [==============================] - 1s 844us/step - loss: 0.3726 - accuracy: 0.8712 - val_loss: 0.3716 - val_accuracy: 0.8750
# Epoch 10/10
# 800/800 [==============================] - 1s 851us/step - loss: 0.3742 - accuracy: 0.8712 - val_loss: 0.3662 - val_accuracy: 0.8750

# %%
# Final evaluation of the model
scores = model_1.evaluate(x_test, y_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))

# Test and train accuracy of the model
model_1_test = scores[1]
model_1_train = max(history_1.history['accuracy'])

# Plotting Train and Test Loss VS no. of epochs
# list of epoch numbers
x = list(range(1,11))

# Validation loss
vy = history_1.history['val_loss']
# Training loss
ty = history_1.history['loss']

# Calling the function to draw the plot
plt_dynamic(x, vy, ty)
# Out:
# Accuracy: 87.50%
